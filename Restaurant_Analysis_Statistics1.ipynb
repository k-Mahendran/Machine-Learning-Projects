# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
ds = pd.read_csv("Restaurant.csv")

# %%
ds.head()
# Out:
#        DATE   TIME  INVOICE_NO     ITEM  QUANTITY  RATE  SUB_TOTAL  AMOUNT  \
# 0  01.10.23  23.40         174  PAROTTA       4.0  18.0       72.0     NaN
# 1  01.10.23  23.40         174  OMLETTE       2.0  18.0       36.0   108.0
# 2  01.10.23  23.36         173     DOSA       3.0  20.0       60.0     NaN
# 3  01.10.23  23.36         173  PAROTTA       2.0  18.0       36.0     NaN
# 4  01.10.23  23.36         173   KALAKI       1.0  15.0       15.0   111.0
#
#    DAY
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1

# %%
# filtering the dates
a = ds[ds["DATE"] == "01.10.23"]

# %%
a.head()
# Out:
#        DATE   TIME  INVOICE_NO     ITEM  QUANTITY  RATE  SUB_TOTAL  AMOUNT  \
# 0  01.10.23  23.40         174  PAROTTA       4.0  18.0       72.0     NaN
# 1  01.10.23  23.40         174  OMLETTE       2.0  18.0       36.0   108.0
# 2  01.10.23  23.36         173     DOSA       3.0  20.0       60.0     NaN
# 3  01.10.23  23.36         173  PAROTTA       2.0  18.0       36.0     NaN
# 4  01.10.23  23.36         173   KALAKI       1.0  15.0       15.0   111.0
#
#    DAY
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1

# %%
# finding the means
a['AMOUNT'].mean()
# Out:
# np.float64(184.2280701754386)

# %%
invoice = ds[ds['INVOICE_NO'] == 117]

# %%
invoice.head()
# Out:
#         DATE   TIME  INVOICE_NO             ITEM  QUANTITY   RATE  SUB_TOTAL  \
# 80  01.10.23  20.29         117       GHEE ROAST       2.0   50.0      100.0
# 81  01.10.23  20.29         117        EGG ROAST       2.0   50.0      100.0
# 82  01.10.23  20.29         117  CHICKEN NOODLES       1.0  100.0      100.0
# 83  01.10.23  20.29         117   CHILLI CHICKEN       1.0  100.0      100.0
# 84  01.10.23  20.29         117      COOL DRINKS       2.0   15.0       30.0
#
#     AMOUNT  DAY
# 80     NaN    1
# 81     NaN    1
# 82     NaN    1
# 83     NaN    1
# 84   430.0    1

# %%
invoice['AMOUNT'].sum()
# Out:
# np.float64(625.0)

# %%
# top 5 sales
sorted_sales = ds.groupby('ITEM')['SUB_TOTAL'].sum().sort_values(ascending=False).head(5)

# %%
sns.barplot(sorted_sales)
# Out:
# <Axes: xlabel='ITEM', ylabel='SUB_TOTAL'>

# %%
# top 5 quantity
sorted_quantity = ds.groupby('ITEM')['QUANTITY'].sum().sort_values(ascending=False).head(5)

# %%
sns.barplot(sorted_quantity)
# Out:
# <Axes: xlabel='ITEM', ylabel='QUANTITY'>

# %%
# task 3 - date(02.10.23) and food sold for least quantity

# %%
aa = ds[ds["DATE"] == "2.10.2023"]

# %%
aa.head()
# Out:
#           DATE   TIME  INVOICE_NO               ITEM  QUANTITY   RATE  \
# 259  2.10.2023  12.29           1   CHICKEN BIRIYANI       1.0  110.0
# 260  2.10.2023  12.32           2  CHICKEN FICE RICE       1.0  100.0
# 261  2.10.2023  12.32           2            GOBI 65       1.0   60.0
# 262  2.10.2023  12.32           2        EGG PAROTTA       1.0   70.0
# 263  2.10.2023  12.34           3            PAROTTA      12.0   18.0
#
#      SUB_TOTAL  AMOUNT  DAY
# 259      110.0   110.0    2
# 260      100.0   230.0    2
# 261       60.0     NaN    2
# 262       70.0     NaN    2
# 263      216.0   296.0    2

# %%
sorted_least_quantity = ds.groupby('ITEM')['QUANTITY'].sum().sort_values(ascending=True).head(5)

# %%
sorted_least_quantity.head()
# Out:
# ITEM
# MISCELLENOUS           0.0
# MISCELLE               0.0
# BOILED EGG             1.0
# BUCKET BIRIYNI HALF    1.0
# CHICKEN HYDERABAD      1.0
# Name: QUANTITY, dtype: float64

# %%
# Task 4 - sorted_Top_Invoice_amountt

# %%
sorted_Top_Invoice_amountt = ds.groupby('INVOICE_NO')['AMOUNT'].sum().sort_values(ascending=False).head(5)

# %%
sorted_Top_Invoice_amountt.head()
# Out:
# INVOICE_NO
# 63     941.0
# 68     892.0
# 66     835.0
# 58     808.0
# 159    768.0
# Name: AMOUNT, dtype: float64

# %%
# Task 5 - Date(1.10.23) and Time(6pm to 9pm). how many parotta sold

# %%
filter_parotta = ds[ds['ITEM'] == 'PAROTTA']
date = filter_parotta[filter_parotta['DATE'] == '01.10.23']

# %%
Time = date[(date['TIME'] >= 18.00) & (date['TIME'] <= 21.00)]

# %%
Time.QUANTITY.sum()
# Out:
# np.float64(34.0)
